# %% [markdown]
# <a href="https://colab.research.google.com/github/JogGiri/pyspark/blob/main/fake_data_with_pyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# !pip install faker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.0 MB/s eta 0:00:00
# ...

# %%
from pyspark.sql import SparkSession
import pandas as pd
import numpy as np
import faker as F

# %%
spark = SparkSession.builder.appName('FakeData').getOrCreate()
fake = F.Faker()

# %%
df = pd.DataFrame(fake.profile() for _ in range(100))
display(df)
# Out:
#                                      job                       company  \
# 0               Secondary school teacher                Fields-Johnson
# 1   Outdoor activities/education manager                   Yang-Murphy
# 2                      Barrister's clerk                   Rodgers Inc
# 3                      Barrister's clerk                  Wilson-White
# 4              Health and safety adviser                  Ward-Jackson
# ..                                   ...                           ...
# 95                        Water engineer                Brown and Sons
# 96                 Scientist, biomedical                  Fisher Group
# 97        Dance movement psychotherapist  Johnson, Schroeder and Allen
# 98       Producer, television/film/video     Wong, Cervantes and Perry
# 99                               Surgeon                 Maldonado PLC
#
#             ssn                                          residence  \
# ...
